# %%
#Just writing this notebook file to see if I get a 200 response. 
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
urls = ["https://www.geeksforgeeks.org/quizzes/sql-basics-quiz-questions"]

all_data = []
for url in urls:
    response = requests.get(url)

print(response.status_code)
# Out:
# 200
