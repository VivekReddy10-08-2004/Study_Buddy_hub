# %%
"""
USM Quiz Scraper (VS Code Version - Structured for SQL Import)
--------------------------------------------------------------
Searches the web (DuckDuckGo + Bing fallback) for quiz resources related
to courses listed in '../data/clean/usm_courses_clean.csv', then converts
them into a structure compatible with the Quiz, Question, and Answer
tables defined in the Quizzes & Flashcards schema.

Output:
    ../data/quiz_data.csv
"""

import pandas as pd
import requests
from bs4 import BeautifulSoup
import time, random, os

# Folder paths
current_dir = os.getcwd()                           # .../scrapers
data_dir = os.path.join(current_dir, "..", "data")  # ../data
clean_dir = os.path.join(data_dir, "clean")         # ../data/clean
os.makedirs(data_dir, exist_ok=True)

input_path = os.path.join(clean_dir, "usm_courses_clean.csv")
output_path = os.path.join(data_dir, "quiz_data.csv")

# Load course data
print(f"Loading courses")
df_courses = pd.read_csv(input_path).dropna(subset=["course_name"]).drop_duplicates()
df_courses = df_courses.head(30)  # limit for testing
print(f"Loaded {len(df_courses)} courses.\n")

# DuckDuckGo / Bing scraping helpers
def duckduckgo_search(query, max_results=5):
    url = "https://duckduckgo.com/html/"
    params = {"q": query}
    headers = {"User-Agent": "Mozilla/5.0"}
    try:
        r = requests.get(url, params=params, headers=headers, timeout=15)
        r.raise_for_status()
    except Exception as e:
        print(f"DuckDuckGo error: {e}")
        return []
    soup = BeautifulSoup(r.text, "html.parser")
    results = []
    for link in soup.select(".result__a")[:max_results]:
        results.append({"title": link.text.strip(), "url": link["href"]})
    return results

def bing_search(query, max_results=5):
    url = "https://www.bing.com/search"
    params = {"q": query}
    headers = {"User-Agent": "Mozilla/5.0"}
    try:
        r = requests.get(url, params=params, headers=headers, timeout=15)
        r.raise_for_status()
    except Exception as e:
        print(f"Bing error: {e}")
        return []
    soup = BeautifulSoup(r.text, "html.parser")
    results = []
    for li in soup.select("li.b_algo")[:max_results]:
        a = li.find("a")
        if a and a.get("href"):
            results.append({"title": a.text.strip(), "url": a["href"]})
    return results

def get_search_results(query, max_results=5):
    results = duckduckgo_search(query, max_results)
    if not results:
        results = bing_search(query, max_results)
    return results

# Main scraper
def gather_quiz_data(df):
    quiz_records = []
    question_records = []
    answer_records = []

    quiz_id = 1
    question_id = 1
    answer_id = 1

    for i, row in df.iterrows():
        course_name = row["course_name"]
        print(f"[{i+1}/{len(df)}] Searching quiz content for: {course_name}")

        quiz_query = f"{course_name} quiz questions PDF OR multiple choice OR test bank"
        results = get_search_results(quiz_query)

        for r in results:
            quiz_title = r["title"][:255]
            quiz_desc = f"Auto-scraped quiz reference for {course_name}"
            quiz_records.append({
                "quiz_id": quiz_id,
                "title": quiz_title,
                "description": quiz_desc,
                "course_name": course_name,
                "creator_id": 1
            })

            # Placeholder simulated questions for structure
            for q_num in range(1, 4):
                q_text = f"Sample Question {q_num} for {quiz_title}"
                q_type = random.choice(["multiple_choice", "true_false", "short_answer"])
                question_records.append({
                    "question_id": question_id,
                    "quiz_id": quiz_id,
                    "question_text": q_text,
                    "question_type": q_type,
                    "points": 1
                })

                if q_type == "multiple_choice":
                    for opt in ["A", "B", "C", "D"]:
                        answer_records.append({
                            "answer_id": answer_id,
                            "question_id": question_id,
                            "answer_text": f"Option {opt} for {q_text}",
                            "is_correct": 1 if opt == "A" else 0
                        })
                        answer_id += 1
                question_id += 1
            quiz_id += 1

        print(f"  Added {len(results)} quizzes for {course_name}")
        time.sleep(2 + random.random())

    quiz_df = pd.DataFrame(quiz_records)
    question_df = pd.DataFrame(question_records)
    answer_df = pd.DataFrame(answer_records)
    return quiz_df, question_df, answer_df

def main():
    print("Starting quiz scraping...")
    quiz_df, question_df, answer_df = gather_quiz_data(df_courses)

    # Save all tables as separate CSVs for import
    quiz_df.to_csv(os.path.join(data_dir, "quiz_table.csv"), index=False, encoding="utf-8")
    question_df.to_csv(os.path.join(data_dir, "question_table.csv"), index=False, encoding="utf-8")
    answer_df.to_csv(os.path.join(data_dir, "answer_table.csv"), index=False, encoding="utf-8")

    print(f"Saved {len(quiz_df)} quizzes, {len(question_df)} questions, {len(answer_df)} answers to the data folder.")

if __name__ == "__main__":
    main()
# Out:
# Loading courses
# Loaded 30 courses.
#
# Starting quiz scraping...
# [1/30] Searching quiz content for: Analysis of Archaeological Materials
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Analysis+of+Archaeological+Materials+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115bebf20>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Analysis of Archaeological Materials
# [2/30] Searching quiz content for: Environmental Archaeology
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Environmental+Archaeology+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115beb680>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Environmental Archaeology
# [3/30] Searching quiz content for: Ethnography: Methods, Ethics, and Practice
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Ethnography%3A+Methods%2C+Ethics%2C+and+Practice+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115bebc20>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Ethnography: Methods, Ethics, and Practice
# [4/30] Searching quiz content for: Anthropology & the Museum
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Anthropology+%26+the+Museum+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115ff7ce0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Anthropology & the Museum
# [5/30] Searching quiz content for: International Development
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=International+Development+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115ff5af0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for International Development
# [6/30] Searching quiz content for: Public Archaeology
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Public+Archaeology+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115ebd9d0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Public Archaeology
# [7/30] Searching quiz content for: African American Historical Archaeology
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=African+American+Historical+Archaeology+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115ed18e0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for African American Historical Archaeology
# [8/30] Searching quiz content for: Topics in Anthropology
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Topics+in+Anthropology+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1165c8950>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Topics in Anthropology
# [9/30] Searching quiz content for: Japan: Archaeology, Environmental History and Multicultural Perspectives
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Japan%3A+Archaeology%2C+Environmental+History+and+Multicultural+Perspectives+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115be9dc0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Japan: Archaeology, Environmental History and Multicultural Perspectives
# [10/30] Searching quiz content for: Topics in Anthropology
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Topics+in+Anthropology+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x11603d850>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Topics in Anthropology
# [11/30] Searching quiz content for: Environmental Archaeology
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Environmental+Archaeology+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115c11700>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Environmental Archaeology
# [12/30] Searching quiz content for: Ethnography: Methods, Ethics, and Practice
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Ethnography%3A+Methods%2C+Ethics%2C+and+Practice+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115c11f10>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Ethnography: Methods, Ethics, and Practice
# [13/30] Searching quiz content for: Public Archaeology
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Public+Archaeology+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115c4d910>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Public Archaeology
# [14/30] Searching quiz content for: Beginning Arabic I
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Beginning+Arabic+I+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1166a67e0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Beginning Arabic I
# [15/30] Searching quiz content for: Beginning Arabic II
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Beginning+Arabic+II+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1166a5970>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Beginning Arabic II
# [16/30] Searching quiz content for: Language Table
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Language+Table+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115dacb60>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Language Table
# [17/30] Searching quiz content for: Intermediate Arabic I
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Intermediate+Arabic+I+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x11675ef30>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Intermediate Arabic I
# [18/30] Searching quiz content for: Intermediate Arabic II
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Intermediate+Arabic+II+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1167f0bf0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Intermediate Arabic II
# [19/30] Searching quiz content for: Cre8: The Art of Creativity
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Cre8%3A+The+Art+of+Creativity+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x11674ce30>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Cre8: The Art of Creativity
# [20/30] Searching quiz content for: Surface, Space, Time (2D)
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Surface%2C+Space%2C+Time+%282D%29+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115c4f800>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Surface, Space, Time (2D)
# [21/30] Searching quiz content for: Surface, Space, Time (3D)
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Surface%2C+Space%2C+Time+%283D%29+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x11677d4c0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Surface, Space, Time (3D)
# [22/30] Searching quiz content for: Fundamentals of Perceptual Drawing
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Fundamentals+of+Perceptual+Drawing+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1166a4da0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Fundamentals of Perceptual Drawing
# [23/30] Searching quiz content for: The Power of Amateur Photography
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=The+Power+of+Amateur+Photography+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115dafef0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for The Power of Amateur Photography
# [24/30] Searching quiz content for: Digital Art & Design
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Digital+Art+%26+Design+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x11688edb0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Digital Art & Design
# [25/30] Searching quiz content for: Introduction to Ceramics I
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Introduction+to+Ceramics+I+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x11688d370>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Introduction to Ceramics I
# [26/30] Searching quiz content for: Introduction to Ceramics II
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Introduction+to+Ceramics+II+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115ebed50>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Introduction to Ceramics II
# [27/30] Searching quiz content for: Introduction to The Visual Book
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Introduction+to+The+Visual+Book+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1169214f0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Introduction to The Visual Book
# [28/30] Searching quiz content for: Drawing: Media and Strategies
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Drawing%3A+Media+and+Strategies+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x116922840>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Drawing: Media and Strategies
# [29/30] Searching quiz content for: Introduction to Painting
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Introduction+to+Painting+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115be90d0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Introduction to Painting
# [30/30] Searching quiz content for: Photography: Analog to Digital
# DuckDuckGo error: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Photography%3A+Analog+to+Digital+quiz+questions+PDF+OR+multiple+choice+OR+test+bank (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x115be9220>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#   Added 5 quizzes for Photography: Analog to Digital
# Saved 150 quizzes, 450 questions, 560 answers to the data folder.
