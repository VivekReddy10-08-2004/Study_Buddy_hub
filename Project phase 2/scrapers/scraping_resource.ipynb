# %%
"""
USM Course Resource Finder (VS Code Version)
--------------------------------------------
Searches DuckDuckGo (with Bing fallback) for educational resources based on
the courses listed in '../data/clean/usm_courses_clean.csv'. All results are
saved to '../data/course_resources.csv'.
"""

import pandas as pd
import time
import requests
from bs4 import BeautifulSoup
import random
import os

# File paths (run from /scrapers)
current_dir = os.getcwd()                            
data_dir = os.path.join(current_dir, "..", "data")   
clean_dir = os.path.join(data_dir, "clean")          
os.makedirs(data_dir, exist_ok=True)

input_path = os.path.join(clean_dir, "usm_courses_clean.csv")
output_path = os.path.join(data_dir, "course_resources.csv")

# Loading cleaned courses
print(f" Loading courses")
df_courses = pd.read_csv(input_path).dropna(subset=["course_name"]).drop_duplicates()

# Optional limit for testing
df_courses = df_courses.head(50)
print(f" Loaded {len(df_courses)} courses to search for resources.\n")

# Searching engine helper functions
def duckduckgo_search(query, max_results=5):
    """Fetch search results from DuckDuckGo."""
    url = "https://duckduckgo.com/html/"
    params = {"q": query}
    headers = {"User-Agent": "Mozilla/5.0"}

    print(f"   [DuckDuckGo] Searching for: {query[:60]}...")
    try:
        r = requests.get(url, params=params, headers=headers, timeout=15)
        print(f"   Response: {r.status_code}, {len(r.text)} bytes")
        r.raise_for_status()
    except Exception as e:
        print(f"   DuckDuckGo failed: {e}")
        return []

    soup = BeautifulSoup(r.text, "html.parser")
    results = []
    for link in soup.select(".result__a")[:max_results]:
        results.append({
            "query": query,
            "title": link.text.strip(),
            "url": link.get("href")
        })

    print(f"    Found {len(results)} results from DuckDuckGo.")
    return results


def bing_search(query, max_results=5):
    """Fetch search results from Bing."""
    url = "https://www.bing.com/search"
    params = {"q": query}
    headers = {"User-Agent": "Mozilla/5.0"}

    print(f"   [Bing] Searching for: {query[:60]}...")
    try:
        r = requests.get(url, params=params, headers=headers, timeout=15)
        print(f"   Response: {r.status_code}, {len(r.text)} bytes")
        r.raise_for_status()
    except Exception as e:
        print(f"    Bing failed: {e}")
        return []

    soup = BeautifulSoup(r.text, "html.parser")
    results = []
    for li in soup.select("li.b_algo")[:max_results]:
        a = li.find("a")
        if a and a.get("href"):
            results.append({
                "query": query,
                "title": a.text.strip(),
                "url": a.get("href")
            })

    print(f"    Found {len(results)} results from Bing.")
    return results

# Combining search function with fallback
def get_resources_for_course(course_name, max_results=5):
    """Try DuckDuckGo first, then Bing if it fails or returns nothing."""
    query = f"{course_name} course resources PDF OR lecture notes OR open courseware"
    results = duckduckgo_search(query, max_results=max_results)
    if not results:
        print(f"    Falling back to Bing for '{course_name}'...")
        results = bing_search(query, max_results=max_results)
    return results

# Gathering resources for all courses
def gather_resources(df):
    all_data = []
    for i, row in df.iterrows():
        course_name = row["course_name"]
        print(f"\n [{i+1}/{len(df)}] Searching resources for: {course_name}")
        try:
            resources = get_resources_for_course(course_name, max_results=5)
            all_data.extend(resources)
        except Exception as e:
            print(f"  Unexpected error for '{course_name}': {e}")
        time.sleep(2 + random.random())  # polite delay
    return all_data

# Running the scraper
def main():
    print(" Starting course resource search...")
    data = gather_resources(df_courses)

    if not data:
        print("\n No resources found. Check your internet connection or try again later.")
        return

    df = pd.DataFrame(data)
    df.drop_duplicates(subset="url", inplace=True)
    df.to_csv(output_path, index=False, encoding="utf-8")

    print(f"\n Done! Saved {len(df)} unique resources to: {output_path}")

if __name__ == "__main__":
    main()
# Out:
#  Loading courses
#  Loaded 50 courses to search for resources.
#
#  Starting course resource search...
#
#  [1/50] Searching resources for: Analysis of Archaeological Materials
#    [DuckDuckGo] Searching for: Analysis of Archaeological Materials course resources PDF OR...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Analysis+of+Archaeological+Materials+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e7a5850>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Analysis of Archaeological Materials'...
#    [Bing] Searching for: Analysis of Archaeological Materials course resources PDF OR...
#    Response: 200, 109423 bytes
#     Found 5 results from Bing.
#
#  [2/50] Searching resources for: Environmental Archaeology
#    [DuckDuckGo] Searching for: Environmental Archaeology course resources PDF OR lecture no...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Environmental+Archaeology+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e7a6ff0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Environmental Archaeology'...
#    [Bing] Searching for: Environmental Archaeology course resources PDF OR lecture no...
#    Response: 200, 101768 bytes
#     Found 5 results from Bing.
#
#  [3/50] Searching resources for: Ethnography: Methods, Ethics, and Practice
#    [DuckDuckGo] Searching for: Ethnography: Methods, Ethics, and Practice course resources ...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Ethnography%3A+Methods%2C+Ethics%2C+and+Practice+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e6196d0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Ethnography: Methods, Ethics, and Practice'...
#    [Bing] Searching for: Ethnography: Methods, Ethics, and Practice course resources ...
#    Response: 200, 100015 bytes
#     Found 5 results from Bing.
#
#  [4/50] Searching resources for: Anthropology & the Museum
#    [DuckDuckGo] Searching for: Anthropology & the Museum course resources PDF OR lecture no...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Anthropology+%26+the+Museum+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10ef85160>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Anthropology & the Museum'...
#    [Bing] Searching for: Anthropology & the Museum course resources PDF OR lecture no...
#    Response: 200, 110103 bytes
#     Found 5 results from Bing.
#
#  [5/50] Searching resources for: International Development
#    [DuckDuckGo] Searching for: International Development course resources PDF OR lecture no...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=International+Development+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10f6eb560>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'International Development'...
#    [Bing] Searching for: International Development course resources PDF OR lecture no...
#    Response: 200, 108737 bytes
#     Found 5 results from Bing.
#
#  [6/50] Searching resources for: Public Archaeology
#    [DuckDuckGo] Searching for: Public Archaeology course resources PDF OR lecture notes OR ...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Public+Archaeology+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10f6eb200>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Public Archaeology'...
#    [Bing] Searching for: Public Archaeology course resources PDF OR lecture notes OR ...
#    Response: 200, 107498 bytes
#     Found 5 results from Bing.
#
#  [7/50] Searching resources for: African American Historical Archaeology
#    [DuckDuckGo] Searching for: African American Historical Archaeology course resources PDF...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=African+American+Historical+Archaeology+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e71b890>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'African American Historical Archaeology'...
#    [Bing] Searching for: African American Historical Archaeology course resources PDF...
#    Response: 200, 102744 bytes
#     Found 5 results from Bing.
#
#  [8/50] Searching resources for: Topics in Anthropology
#    [DuckDuckGo] Searching for: Topics in Anthropology course resources PDF OR lecture notes...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Topics+in+Anthropology+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10f792090>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Topics in Anthropology'...
#    [Bing] Searching for: Topics in Anthropology course resources PDF OR lecture notes...
#    Response: 200, 108559 bytes
#     Found 5 results from Bing.
#
#  [9/50] Searching resources for: Japan: Archaeology, Environmental History and Multicultural Perspectives
#    [DuckDuckGo] Searching for: Japan: Archaeology, Environmental History and Multicultural ...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Japan%3A+Archaeology%2C+Environmental+History+and+Multicultural+Perspectives+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10f816630>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Japan: Archaeology, Environmental History and Multicultural Perspectives'...
#    [Bing] Searching for: Japan: Archaeology, Environmental History and Multicultural ...
#    Response: 200, 109644 bytes
#     Found 5 results from Bing.
#
#  [10/50] Searching resources for: Topics in Anthropology
#    [DuckDuckGo] Searching for: Topics in Anthropology course resources PDF OR lecture notes...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Topics+in+Anthropology+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e7bbb30>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Topics in Anthropology'...
#    [Bing] Searching for: Topics in Anthropology course resources PDF OR lecture notes...
#    Response: 200, 108423 bytes
#     Found 5 results from Bing.
#
#  [11/50] Searching resources for: Environmental Archaeology
#    [DuckDuckGo] Searching for: Environmental Archaeology course resources PDF OR lecture no...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Environmental+Archaeology+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e7bbb60>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Environmental Archaeology'...
#    [Bing] Searching for: Environmental Archaeology course resources PDF OR lecture no...
#    Response: 200, 108127 bytes
#     Found 5 results from Bing.
#
#  [12/50] Searching resources for: Ethnography: Methods, Ethics, and Practice
#    [DuckDuckGo] Searching for: Ethnography: Methods, Ethics, and Practice course resources ...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Ethnography%3A+Methods%2C+Ethics%2C+and+Practice+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10f7d0170>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Ethnography: Methods, Ethics, and Practice'...
#    [Bing] Searching for: Ethnography: Methods, Ethics, and Practice course resources ...
#    Response: 200, 101543 bytes
#     Found 5 results from Bing.
#
#  [13/50] Searching resources for: Public Archaeology
#    [DuckDuckGo] Searching for: Public Archaeology course resources PDF OR lecture notes OR ...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Public+Archaeology+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e5d03e0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Public Archaeology'...
#    [Bing] Searching for: Public Archaeology course resources PDF OR lecture notes OR ...
#    Response: 200, 107332 bytes
#     Found 5 results from Bing.
#
#  [14/50] Searching resources for: Beginning Arabic I
#    [DuckDuckGo] Searching for: Beginning Arabic I course resources PDF OR lecture notes OR ...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Beginning+Arabic+I+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e5d0830>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Beginning Arabic I'...
#    [Bing] Searching for: Beginning Arabic I course resources PDF OR lecture notes OR ...
#    Response: 200, 111298 bytes
#     Found 5 results from Bing.
#
#  [15/50] Searching resources for: Beginning Arabic II
#    [DuckDuckGo] Searching for: Beginning Arabic II course resources PDF OR lecture notes OR...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Beginning+Arabic+II+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e7d9e50>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Beginning Arabic II'...
#    [Bing] Searching for: Beginning Arabic II course resources PDF OR lecture notes OR...
#    Response: 200, 110928 bytes
#     Found 5 results from Bing.
#
#  [16/50] Searching resources for: Language Table
#    [DuckDuckGo] Searching for: Language Table course resources PDF OR lecture notes OR open...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Language+Table+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10efd0e90>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Language Table'...
#    [Bing] Searching for: Language Table course resources PDF OR lecture notes OR open...
#    Response: 200, 107319 bytes
#     Found 5 results from Bing.
#
#  [17/50] Searching resources for: Intermediate Arabic I
#    [DuckDuckGo] Searching for: Intermediate Arabic I course resources PDF OR lecture notes ...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Intermediate+Arabic+I+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e6b7cb0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Intermediate Arabic I'...
#    [Bing] Searching for: Intermediate Arabic I course resources PDF OR lecture notes ...
#    Response: 200, 99283 bytes
#     Found 5 results from Bing.
#
#  [18/50] Searching resources for: Intermediate Arabic II
#    [DuckDuckGo] Searching for: Intermediate Arabic II course resources PDF OR lecture notes...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Intermediate+Arabic+II+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e4f7230>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Intermediate Arabic II'...
#    [Bing] Searching for: Intermediate Arabic II course resources PDF OR lecture notes...
#    Response: 200, 108802 bytes
#     Found 5 results from Bing.
#
#  [19/50] Searching resources for: Cre8: The Art of Creativity
#    [DuckDuckGo] Searching for: Cre8: The Art of Creativity course resources PDF OR lecture ...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Cre8%3A+The+Art+of+Creativity+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10ef03230>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Cre8: The Art of Creativity'...
#    [Bing] Searching for: Cre8: The Art of Creativity course resources PDF OR lecture ...
#    Response: 200, 108174 bytes
#     Found 5 results from Bing.
#
#  [20/50] Searching resources for: Surface, Space, Time (2D)
#    [DuckDuckGo] Searching for: Surface, Space, Time (2D) course resources PDF OR lecture no...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Surface%2C+Space%2C+Time+%282D%29+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e8c00e0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Surface, Space, Time (2D)'...
#    [Bing] Searching for: Surface, Space, Time (2D) course resources PDF OR lecture no...
#    Response: 200, 107830 bytes
#     Found 5 results from Bing.
#
#  [21/50] Searching resources for: Surface, Space, Time (3D)
#    [DuckDuckGo] Searching for: Surface, Space, Time (3D) course resources PDF OR lecture no...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Surface%2C+Space%2C+Time+%283D%29+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e562bd0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Surface, Space, Time (3D)'...
#    [Bing] Searching for: Surface, Space, Time (3D) course resources PDF OR lecture no...
#    Response: 200, 107605 bytes
#     Found 5 results from Bing.
#
#  [22/50] Searching resources for: Fundamentals of Perceptual Drawing
#    [DuckDuckGo] Searching for: Fundamentals of Perceptual Drawing course resources PDF OR l...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Fundamentals+of+Perceptual+Drawing+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e58baa0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Fundamentals of Perceptual Drawing'...
#    [Bing] Searching for: Fundamentals of Perceptual Drawing course resources PDF OR l...
#    Response: 200, 103195 bytes
#     Found 5 results from Bing.
#
#  [23/50] Searching resources for: The Power of Amateur Photography
#    [DuckDuckGo] Searching for: The Power of Amateur Photography course resources PDF OR lec...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=The+Power+of+Amateur+Photography+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e64b530>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'The Power of Amateur Photography'...
#    [Bing] Searching for: The Power of Amateur Photography course resources PDF OR lec...
#    Response: 200, 104790 bytes
#     Found 5 results from Bing.
#
#  [24/50] Searching resources for: Digital Art & Design
#    [DuckDuckGo] Searching for: Digital Art & Design course resources PDF OR lecture notes O...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Digital+Art+%26+Design+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e8c9760>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Digital Art & Design'...
#    [Bing] Searching for: Digital Art & Design course resources PDF OR lecture notes O...
#    Response: 200, 107031 bytes
#     Found 5 results from Bing.
#
#  [25/50] Searching resources for: Introduction to Ceramics I
#    [DuckDuckGo] Searching for: Introduction to Ceramics I course resources PDF OR lecture n...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Introduction+to+Ceramics+I+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e8c9520>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Introduction to Ceramics I'...
#    [Bing] Searching for: Introduction to Ceramics I course resources PDF OR lecture n...
#    Response: 200, 109569 bytes
#     Found 5 results from Bing.
#
#  [26/50] Searching resources for: Introduction to Ceramics II
#    [DuckDuckGo] Searching for: Introduction to Ceramics II course resources PDF OR lecture ...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Introduction+to+Ceramics+II+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e69ca10>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Introduction to Ceramics II'...
#    [Bing] Searching for: Introduction to Ceramics II course resources PDF OR lecture ...
#    Response: 200, 108468 bytes
#     Found 5 results from Bing.
#
#  [27/50] Searching resources for: Introduction to The Visual Book
#    [DuckDuckGo] Searching for: Introduction to The Visual Book course resources PDF OR lect...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Introduction+to+The+Visual+Book+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e69cfb0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Introduction to The Visual Book'...
#    [Bing] Searching for: Introduction to The Visual Book course resources PDF OR lect...
#    Response: 200, 106940 bytes
#     Found 5 results from Bing.
#
#  [28/50] Searching resources for: Drawing: Media and Strategies
#    [DuckDuckGo] Searching for: Drawing: Media and Strategies course resources PDF OR lectur...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Drawing%3A+Media+and+Strategies+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e8cb680>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Drawing: Media and Strategies'...
#    [Bing] Searching for: Drawing: Media and Strategies course resources PDF OR lectur...
#    Response: 200, 106851 bytes
#     Found 5 results from Bing.
#
#  [29/50] Searching resources for: Introduction to Painting
#    [DuckDuckGo] Searching for: Introduction to Painting course resources PDF OR lecture not...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Introduction+to+Painting+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e64b890>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Introduction to Painting'...
#    [Bing] Searching for: Introduction to Painting course resources PDF OR lecture not...
#    Response: 200, 107460 bytes
#     Found 5 results from Bing.
#
#  [30/50] Searching resources for: Photography: Analog to Digital
#    [DuckDuckGo] Searching for: Photography: Analog to Digital course resources PDF OR lectu...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Photography%3A+Analog+to+Digital+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e6b5af0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Photography: Analog to Digital'...
#    [Bing] Searching for: Photography: Analog to Digital course resources PDF OR lectu...
#    Response: 200, 101039 bytes
#     Found 5 results from Bing.
#
#  [31/50] Searching resources for: Introduction to Printmaking: Intaglio and Relief
#    [DuckDuckGo] Searching for: Introduction to Printmaking: Intaglio and Relief course reso...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Introduction+to+Printmaking%3A+Intaglio+and+Relief+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e6b5e80>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Introduction to Printmaking: Intaglio and Relief'...
#    [Bing] Searching for: Introduction to Printmaking: Intaglio and Relief course reso...
#    Response: 200, 109615 bytes
#     Found 5 results from Bing.
#
#  [32/50] Searching resources for: Introduction to Printmaking: Lithography and Screen Printing
#    [DuckDuckGo] Searching for: Introduction to Printmaking: Lithography and Screen Printing...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Introduction+to+Printmaking%3A+Lithography+and+Screen+Printing+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e78bb90>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Introduction to Printmaking: Lithography and Screen Printing'...
#    [Bing] Searching for: Introduction to Printmaking: Lithography and Screen Printing...
#    Response: 200, 108970 bytes
#     Found 5 results from Bing.
#
#  [33/50] Searching resources for: Sculpture: Additive and Subtractive Processes
#    [DuckDuckGo] Searching for: Sculpture: Additive and Subtractive Processes course resourc...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Sculpture%3A+Additive+and+Subtractive+Processes+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10ef85490>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Sculpture: Additive and Subtractive Processes'...
#    [Bing] Searching for: Sculpture: Additive and Subtractive Processes course resourc...
#    Response: 200, 111116 bytes
#     Found 5 results from Bing.
#
#  [34/50] Searching resources for: Sculpture: Altered and Constructed Processes
#    [DuckDuckGo] Searching for: Sculpture: Altered and Constructed Processes course resource...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Sculpture%3A+Altered+and+Constructed+Processes+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e4f53d0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Sculpture: Altered and Constructed Processes'...
#    [Bing] Searching for: Sculpture: Altered and Constructed Processes course resource...
#    Response: 200, 102444 bytes
#     Found 5 results from Bing.
#
#  [35/50] Searching resources for: Topics in Studio Art
#    [DuckDuckGo] Searching for: Topics in Studio Art course resources PDF OR lecture notes O...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Topics+in+Studio+Art+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10f07d490>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Topics in Studio Art'...
#    [Bing] Searching for: Topics in Studio Art course resources PDF OR lecture notes O...
#    Response: 200, 107406 bytes
#     Found 5 results from Bing.
#
#  [36/50] Searching resources for: Exploring Time-Based Art & Design
#    [DuckDuckGo] Searching for: Exploring Time-Based Art & Design course resources PDF OR le...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Exploring+Time-Based+Art+%26+Design+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e5eaff0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Exploring Time-Based Art & Design'...
#    [Bing] Searching for: Exploring Time-Based Art & Design course resources PDF OR le...
#    Response: 200, 103798 bytes
#     Found 5 results from Bing.
#
#  [37/50] Searching resources for: Intermediate Ceramics
#    [DuckDuckGo] Searching for: Intermediate Ceramics course resources PDF OR lecture notes ...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Intermediate+Ceramics+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e6e9520>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Intermediate Ceramics'...
#    [Bing] Searching for: Intermediate Ceramics course resources PDF OR lecture notes ...
#    Response: 200, 107388 bytes
#     Found 5 results from Bing.
#
#  [38/50] Searching resources for: The Visual Book II: Historical Influences on Contemporary Artists’ Books
#    [DuckDuckGo] Searching for: The Visual Book II: Historical Influences on Contemporary Ar...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=The+Visual+Book+II%3A+Historical+Influences+on+Contemporary+Artists%E2%80%99+Books+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10f25d430>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'The Visual Book II: Historical Influences on Contemporary Artists’ Books'...
#    [Bing] Searching for: The Visual Book II: Historical Influences on Contemporary Ar...
#    Response: 200, 106518 bytes
#     Found 5 results from Bing.
#
#  [39/50] Searching resources for: Book Arts Summer Workshop
#    [DuckDuckGo] Searching for: Book Arts Summer Workshop course resources PDF OR lecture no...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Book+Arts+Summer+Workshop+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10f0d5190>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Book Arts Summer Workshop'...
#    [Bing] Searching for: Book Arts Summer Workshop course resources PDF OR lecture no...
#    Response: 200, 109414 bytes
#     Found 5 results from Bing.
#
#  [40/50] Searching resources for: Experimental Drawing
#    [DuckDuckGo] Searching for: Experimental Drawing course resources PDF OR lecture notes O...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Experimental+Drawing+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10eeefd10>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Experimental Drawing'...
#    [Bing] Searching for: Experimental Drawing course resources PDF OR lecture notes O...
#    Response: 200, 110789 bytes
#     Found 5 results from Bing.
#
#  [41/50] Searching resources for: Intermediate Drawing and Painting: The Figure
#    [DuckDuckGo] Searching for: Intermediate Drawing and Painting: The Figure course resourc...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Intermediate+Drawing+and+Painting%3A+The+Figure+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e563d70>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Intermediate Drawing and Painting: The Figure'...
#    [Bing] Searching for: Intermediate Drawing and Painting: The Figure course resourc...
#    Response: 200, 116264 bytes
#     Found 5 results from Bing.
#
#  [42/50] Searching resources for: Digital Photography
#    [DuckDuckGo] Searching for: Digital Photography course resources PDF OR lecture notes OR...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Digital+Photography+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10f792bd0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Digital Photography'...
#    [Bing] Searching for: Digital Photography course resources PDF OR lecture notes OR...
#    Response: 200, 107998 bytes
#     Found 5 results from Bing.
#
#  [43/50] Searching resources for: Experimental Printmaking
#    [DuckDuckGo] Searching for: Experimental Printmaking course resources PDF OR lecture not...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Experimental+Printmaking+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10f793290>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Experimental Printmaking'...
#    [Bing] Searching for: Experimental Printmaking course resources PDF OR lecture not...
#    Response: 200, 109100 bytes
#     Found 5 results from Bing.
#
#  [44/50] Searching resources for: Topics in Sculpture
#    [DuckDuckGo] Searching for: Topics in Sculpture course resources PDF OR lecture notes OR...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Topics+in+Sculpture+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e8ca900>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Topics in Sculpture'...
#    [Bing] Searching for: Topics in Sculpture course resources PDF OR lecture notes OR...
#    Response: 200, 109607 bytes
#     Found 5 results from Bing.
#
#  [45/50] Searching resources for: Internship in the Visual Arts
#    [DuckDuckGo] Searching for: Internship in the Visual Arts course resources PDF OR lectur...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Internship+in+the+Visual+Arts+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10f67f710>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Internship in the Visual Arts'...
#    [Bing] Searching for: Internship in the Visual Arts course resources PDF OR lectur...
#    Response: 200, 95098 bytes
#     Found 2 results from Bing.
#
#  [46/50] Searching resources for: Senior Seminar in Studio Art
#    [DuckDuckGo] Searching for: Senior Seminar in Studio Art course resources PDF OR lecture...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Senior+Seminar+in+Studio+Art+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e7b5ee0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Senior Seminar in Studio Art'...
#    [Bing] Searching for: Senior Seminar in Studio Art course resources PDF OR lecture...
#    Response: 200, 99378 bytes
#     Found 5 results from Bing.
#
#  [47/50] Searching resources for: Advanced Problems in Art
#    [DuckDuckGo] Searching for: Advanced Problems in Art course resources PDF OR lecture not...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Advanced+Problems+in+Art+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10e7b48c0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Advanced Problems in Art'...
#    [Bing] Searching for: Advanced Problems in Art course resources PDF OR lecture not...
#    Response: 200, 110774 bytes
#     Found 5 results from Bing.
#
#  [48/50] Searching resources for: Independent Study in Art
#    [DuckDuckGo] Searching for: Independent Study in Art course resources PDF OR lecture not...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Independent+Study+in+Art+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10f09fda0>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Independent Study in Art'...
#    [Bing] Searching for: Independent Study in Art course resources PDF OR lecture not...
#    Response: 200, 108639 bytes
#     Found 5 results from Bing.
#
#  [49/50] Searching resources for: Topics in Studio Art
#    [DuckDuckGo] Searching for: Topics in Studio Art course resources PDF OR lecture notes O...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Topics+in+Studio+Art+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10f6a8a10>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Topics in Studio Art'...
#    [Bing] Searching for: Topics in Studio Art course resources PDF OR lecture notes O...
#    Response: 200, 107410 bytes
#     Found 5 results from Bing.
#
#  [50/50] Searching resources for: Advanced Ceramics I
#    [DuckDuckGo] Searching for: Advanced Ceramics I course resources PDF OR lecture notes OR...
#    DuckDuckGo failed: HTTPSConnectionPool(host='duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=Advanced+Ceramics+I+course+resources+PDF+OR+lecture+notes+OR+open+courseware (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10f6a9610>, 'Connection to duckduckgo.com timed out. (connect timeout=15)'))
#     Falling back to Bing for 'Advanced Ceramics I'...
#    [Bing] Searching for: Advanced Ceramics I course resources PDF OR lecture notes OR...
#    Response: 200, 109596 bytes
#     Found 5 results from Bing.
#
#  Done! Saved 247 unique resources to: /Users/sarahkayembe/Documents/Database_cos557/Study_Buddy_hub/Project phase 2/scrapers/../data/course_resources.csv
